# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/Decision-tree/blob/main/Machine_learning_tree_concept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
df=pd.read_excel("/content/music.csv.xlsx")
df
# Out:
#     age  gender      genre
# 0    20       1     Hippop
# 1    23       1     Hippop
# 2    25       1     Hippop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1   Classica
# 8    37       1   Classica
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0  Acoustics
# 13   27       0  Acoustics
# 14   30       0  Acoustics
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
x=df.drop(columns=["genre"])
x
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
y=df['genre']
y
# Out:
# 0        Hippop
# 1        Hippop
# 2        Hippop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7      Classica
# 8      Classica
# 9         Dance
# 10        Dance
# 11        Dance
# 12    Acoustics
# 13    Acoustics
# 14    Acoustics
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
tree.export_graphviz(model,out_file="music-recommender.dot",feature_names=["age","gender"],class_names=sorted(y.unique()),label="all",rounded=True,filled=True)
